# %%
c1 = "1b45090a00451f030a4c1749081d1e15015302004e10061d55024516064100060054041b1a051a410f1c52030e00000b075208131441a2c9a2cf06530f134f4f5006091541071d1c54011310"
c2 = "0e00070a1d1107181a0d560c15150f1a1c410c4f0a15490f0106560d0141000c5304061d070811490a06060c41064d0545560807140ee3c3a2d04f520b061d41034f00000007061d101a0602"

# %%
print len(c1)
print len(c2)
# Out:
# 152
# 152

# %%
def xor(a, b):
    return "".join(["%x" % (int(x,16) ^ int(y,16)) for (x, y) in zip(a, b)])

# %%
hex_str = xor(c1, c2)
print hex_str
print len(hex_str)
# Out:
# 15450e001d54181b104141451d08110f1d120e4f44054f125404131b0700000a535002061d0d0b08051a540f4f064d0e42040014004f410a001f49010415520e5349091541001b01441b1512
# 152

# %% [markdown]
# # Artigos

# %%
print " a ".encode("hex")
print " o ".encode("hex")
print " um ".encode("hex")
print " uma ".encode("hex")
# Out:
# 206120
# 206f20
# 20756d20
# 20756d6120

# %%
print "206120".decode("hex")
print "206f20".decode("hex")
print "20756d20".decode("hex")
print "20756d6120".decode("hex")
# Out:
#  a
#  o
#  um
#  uma

# %%
# a
hex_len = 6
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " a ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 5$. 0:6
# t1� 1:7
# eo  2:8
# p�! 3:9
# .a= 4:10
# �`� 5:11
#  |t 6:12
# !�a 7:13
# =58 8:14
# � � 9:15
# ty; 10:16
# a� 11:17
# 8z0 12:18
# ��$ 13:19
# ;qa 14:20
# �e4 15:21
# 0 a 16:22
# $u4 17:23
# a e 18:24
# 4uq 19:25
# a$= 20:26
# 40� 21:27
# e|( 22:28
# q�� 23:29
# =i1 24:30
# ��0 25:31
# (p/ 26:32
# �q� 27:33
# 1n= 28:34
# 0�� 29:35
# /|2 30:36
# Ѱ 31:37
# =s. 32:38
# �A� 33:39
# 2oo 34:40
# �� 35:41
# ..d 36:42
# ĕ` 37:43
# o%% 38:44
# �!t 39:45
# ddo 40:46
# `5� 41:47
# %.2 42:48
# t� 43:49
# ost 44:50
# �D` 45:51
# 25$ 46:52
# !a 47:53
# te3 48:54
# `  49:55
# $r; 50:56
# aP� 51:57
# 3z' 52:58
# �P 53:59
# ;f  54:60
# �  55:61
# 'a  56:62
# Pa  57:63
#  a* 58:64
#  a� 59:65
#  ks 60:66
#  � 61:67
# *2p 62:68
# �T  63:69
# s1" 64:70
# a 65:71
# pc& 66:72
#  AA 67:73
# "g= 68:74
# � 69:75
# &|- 70:76
# A�� 71:77
# =l+ 72:78
# � 73:79
# -j( 74:80
# �Ѡ 75:81
# +i% 76:82
# ��q 77:83
# (d: 78:84
# �0� 79:85
# %{t 80:86
# q�` 81:87
# :5/ 82:88
# �!� 83:89
# tno 84:90
# `�� 85:91
# ...

# %%
# o
hex_len = 6
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " o ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 5*. 0:6
# t?� 1:7
# ea  2:8
# p�! 3:9
# .o= 4:10
# �n� 5:11
#  rt 6:12
# !�a 7:13
# =;8 8:14
# �.� 9:15
# tw; 10:16
# a� 11:17
# 8t0 12:18
# ��$ 13:19
# ;a 14:20
# �k4 15:21
# 0.a 16:22
# ${4 17:23
# a.e 18:24
# 4{q 19:25
# a*= 20:26
# 4>� 21:27
# er( 22:28
# q�� 23:29
# =g1 24:30
# ��0 25:31
# (~/ 26:32
# �� 27:33
# 1`= 28:34
# 0�� 29:35
# /r2 30:36
# Ѿ 31:37
# =}. 32:38
# �O� 33:39
# 2ao 34:40
# �� 35:41
# . d 36:42
# ě` 37:43
# o+% 38:44
# �/t 39:45
# djo 40:46
# `;� 41:47
# % 2 42:48
# t� 43:49
# o}t 44:50
# �J` 45:51
# 2;$ 46:52
# /a 47:53
# tk3 48:54
# `. 49:55
# $|; 50:56
# a^� 51:57
# 3t' 52:58
# �P 53:59
# ;h  54:60
# �  55:61
# 'o  56:62
# Po  57:63
#  o* 58:64
#  o� 59:65
#  es 60:66
#  � 61:67
# *<p 62:68
# �Z  63:69
# s?" 64:70
# o 65:71
# pm& 66:72
#  OA 67:73
# "i= 68:74
# � 69:75
# &r- 70:76
# A�� 71:77
# =b+ 72:78
# � 73:79
# -d( 74:80
# �ߠ 75:81
# +g% 76:82
# ��q 77:83
# (j: 78:84
# �>� 79:85
# %ut 80:86
# q�` 81:87
# :;/ 82:88
# �/� 83:89
# t`o 84:90
# `�� 85:91
# ...

# %%
# um
hex_len = 8
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " um ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 50c  0:8
# t%�! 1:9
# e{m= 2:10
# p�l� 3:11
# .upt 4:12
# �t�a 5:13
#  h98 6:14
# !�,� 7:15
# =!u; 8:16
# �4� 9:17
# tmv0 10:18
# a��$ 11:19
# 8n}a 12:20
# ��i4 13:21
# ;e,a 14:22
# �qy4 15:23
# 04,e 16:24
# $ayq 17:25
# a4(= 18:26
# 4a<� 19:27
# a0p( 20:28
# 4$�� 21:29
# ehe1 22:30
# q��0 23:31
# =}|/ 24:32
# ��}� 25:33
# (db= 26:34
# �e�� 27:35
# 1zp2 28:36
# 0�� 29:37
# /h. 30:38
# ѤM� 31:39
# =gco 32:40
# �U�� 33:41
# 2{"d 34:42
# ��` 35:43
# .:)% 36:44
# ā-t 37:45
# o1ho 38:46
# �59� 39:47
# dp"2 40:48
# `!� 41:49
# %:t 42:50
# t�H` 43:51
# og9$ 44:52
# �P-a 45:53
# 2!i3 46:54
# 5, 47:55
# tq~; 48:56
# `4\� 49:57
# $fv' 50:58
# aD�P 51:59
# 3nj  52:60
# �  53:61
# ;rm  54:62
# �m  55:63
# 'um* 56:64
# Pum� 57:65
#  ugs 58:66
#  u� 59:67
#  >p 60:68
#  �X  61:69
# *&=" 62:70
# �@m 63:71
# s%o& 64:72
# uMA 65:73
# pwk= 66:74
#  U� 67:75
# "sp- 68:76
# �� 69:77
# &h`+ 70:78
# A��� 71:79
# =xf( 72:80
# �ݠ 73:81
# -~e% 74:82
# ���q 75:83
# +}h: 76:84
# ��<� 77:85
# (pwt 78:86
# ...

# %%
# uma
hex_len = 10
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " uma ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 50ca= 0:10
# t%�`� 1:11
# e{m|t 2:12
# p�l�a 3:13
# .up58 4:14
# �t� � 5:15
#  h9y; 6:16
# !�,� 7:17
# =!uz0 8:18
# �4��$ 9:19
# tmvqa 10:20
# a��e4 11:21
# 8n} a 12:22
# ��iu4 13:23
# ;e, e 14:24
# �qyuq 15:25
# 04,$= 16:26
# $ay0� 17:27
# a4(|( 18:28
# 4a<�� 19:29
# a0pi1 20:30
# 4$��0 21:31
# ehep/ 22:32
# q��q� 23:33
# =}|n= 24:34
# ��}�� 25:35
# (db|2 26:36
# �e�� 27:37
# 1zps. 28:38
# 0��A� 29:39
# /hoo 30:40
# ѤM�� 31:41
# =gc.d 32:42
# �U��` 33:43
# 2{"%% 34:44
# ��!t 35:45
# .:)do 36:46
# ā-5� 37:47
# o1h.2 38:48
# �59� 39:49
# dp"st 40:50
# `!�D` 41:51
# %:5$ 42:52
# t�H!a 43:53
# og9e3 44:54
# �P-  45:55
# 2!ir; 46:56
# 5,P� 47:57
# tq~z' 48:58
# `4\�P 49:59
# $fvf  50:60
# aD�  51:61
# 3nja  52:62
# �a  53:63
# ;rma* 54:64
# �ma� 55:65
# 'umks 56:66
# Pum� 57:67
#  ug2p 58:68
#  u�T  59:69
#  >1" 60:70
#  �Xa 61:71
# *&=c& 62:72
# �@mAA 63:73
# s%og= 64:74
# uM� 65:75
# pwk|- 66:76
#  U�� 67:77
# "spl+ 68:78
# ��� 69:79
# &h`j( 70:80
# A��Ѡ 71:81
# =xfi% 72:82
# ...

# %% [markdown]
# # Preposições

# %%
print " de ".encode("hex")
print " em ".encode("hex")
print " para ".encode("hex")
print " por ".encode("hex")
print " com ".encode("hex")
# Out:
# 20646520
# 20656d20
# 207061726120
# 20706f7220
# 20636f6d20

# %%
print "20646520".decode("hex")
print "20656d20".decode("hex")
print "207061726120".decode("hex")
print "20706f7220".decode("hex")
print "20636f6d20".decode("hex")
# Out:
#  de
#  em
#  para
#  por
#  com

# %%
# de
hex_len = 8
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " de ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 5!k  0:8
# t4�! 1:9
# eje= 2:10
# p�d� 3:11
# .dxt 4:12
# �e�a 5:13
#  y18 6:14
# !�$� 7:15
# =0}; 8:16
# �%� 9:17
# t|~0 10:18
# a��$ 11:19
# 8ua 12:20
# ��a4 13:21
# ;t$a 14:22
# �`q4 15:23
# 0%$e 16:24
# $pqq 17:25
# a% = 18:26
# 4p4� 19:27
# a!x( 20:28
# 45�� 21:29
# eym1 22:30
# q��0 23:31
# =lt/ 24:32
# ��u� 25:33
# (uj= 26:34
# �t�� 27:35
# 1kx2 28:36
# 0�� 29:37
# /yw. 30:38
# ѵE� 31:39
# =vko 32:40
# �D�� 33:41
# 2j*d 34:42
# ��` 35:43
# .+!% 36:44
# Đ%t 37:45
# o `o 38:46
# �$1� 39:47
# da*2 40:48
# `0� 41:49
# %+wt 42:50
# t�@` 43:51
# ov1$ 44:52
# �A%a 45:53
# 20a3 46:54
# $$ 47:55
# t`v; 48:56
# `%T� 49:57
# $w~' 50:58
# aU�P 51:59
# 3b  52:60
# �  53:61
# ;ce  54:62
# �e  55:63
# 'de* 56:64
# Pde� 57:65
#  dos 58:66
#  d� 59:67
#  n6p 60:68
#  �P  61:69
# *75" 62:70
# �Qe 63:71
# s4g& 64:72
# dEA 65:73
# pfc= 66:74
#  D� 67:75
# "bx- 68:76
# �� 69:77
# &yh+ 70:78
# A��� 71:79
# =in( 72:80
# �ՠ 73:81
# -om% 74:82
# ���q 75:83
# +l`: 76:84
# ��4� 77:85
# (at 78:86
# ...

# %%
# em
hex_len = 8
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " em ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 5 c  0:8
# t5�! 1:9
# ekm= 2:10
# p�l� 3:11
# .ept 4:12
# �d�a 5:13
#  x98 6:14
# !�,� 7:15
# =1u; 8:16
# �$� 9:17
# t}v0 10:18
# a��$ 11:19
# 8~}a 12:20
# ��i4 13:21
# ;u,a 14:22
# �ay4 15:23
# 0$,e 16:24
# $qyq 17:25
# a$(= 18:26
# 4q<� 19:27
# a p( 20:28
# 44�� 21:29
# exe1 22:30
# q��0 23:31
# =m|/ 24:32
# ��}� 25:33
# (tb= 26:34
# �u�� 27:35
# 1jp2 28:36
# 0�� 29:37
# /x. 30:38
# ѴM� 31:39
# =wco 32:40
# �E�� 33:41
# 2k"d 34:42
# ��` 35:43
# .*)% 36:44
# đ-t 37:45
# o!ho 38:46
# �%9� 39:47
# d`"2 40:48
# `1� 41:49
# %*t 42:50
# t�H` 43:51
# ow9$ 44:52
# �@-a 45:53
# 21i3 46:54
# %, 47:55
# ta~; 48:56
# `$\� 49:57
# $vv' 50:58
# aT�P 51:59
# 3~j  52:60
# �  53:61
# ;bm  54:62
# �m  55:63
# 'em* 56:64
# Pem� 57:65
#  egs 58:66
#  e� 59:67
#  o>p 60:68
#  �X  61:69
# *6=" 62:70
# �Pm 63:71
# s5o& 64:72
# eMA 65:73
# pgk= 66:74
#  E� 67:75
# "cp- 68:76
# �� 69:77
# &x`+ 70:78
# A��� 71:79
# =hf( 72:80
# �ݠ 73:81
# -ne% 74:82
# ���q 75:83
# +mh: 76:84
# ��<� 77:85
# (`wt 78:86
# ...

# %%
# para
hex_len = 12
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " para ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 55or|t 0:12
# t �s�a 1:13
# e~ao58 2:14
# p�`� � 3:15
# .p|&y; 4:16
# �q�3� 5:17
#  m5jz0 6:18
# !� ��$ 7:19
# =$yiqa 8:20
# �1��e4 9:21
# thzb a 10:22
# a��vu4 11:23
# 8kq3 e 12:24
# ��efuq 13:25
# ;` 3$= 14:26
# �tuf0� 15:27
# 01 7|( 16:28
# $du#�� 17:29
# a1$oi1 18:30
# 4d0��0 19:31
# a5|zp/ 20:32
# 4!��q� 21:33
# emicn= 22:34
# q��b�� 23:35
# =xp}|2 24:36
# ��q�� 25:37
# (anos. 26:38
# �`��A� 27:39
# 1|`oo 28:40
# 0��R�� 29:41
# /ms|.d 30:42
# ѡA��` 31:43
# =bo=%% 32:44
# �P��!t 33:45
# 2~.6do 34:46
# ��25� 35:47
# .?%w.2 36:48
# Ą!&� 37:49
# o4d=st 38:50
# �05�D` 39:51
# du.`5$ 40:52
# `$�W!a 41:53
# %?s&e3 42:54
# t�D2  43:55
# ob5vr; 44:56
# �U!3P� 45:57
# 2$eaz' 46:58
# 0 C�P 47:59
# ttrif  48:60
# `1P�  49:61
# $czua  50:62
# aA�a  51:63
# 3kfra* 52:64
# �ra� 53:65
# ;warks 54:66
# �ar� 55:67
# 'pax2p 56:68
# Ppa�T  57:69
#  pk!1" 58:70
#  p�Ga 59:71
#  z2"c& 60:72
#  �TrAA 61:73
# *#1pg= 62:74
# �EaR� 63:75
# s ct|- 64:76
# pA�� 65:77
# prgol+ 66:78
#  P��� 67:79
# ...

# %%
# por
hex_len = 10
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " por ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 55ar= 0:10
# t �s� 1:11
# e~oot 2:12
# p�n�a 3:13
# .pr&8 4:14
# �q�3� 5:15
#  m;j; 6:16
# !�.� 7:17
# =$wi0 8:18
# �1��$ 9:19
# thtba 10:20
# a��v4 11:21
# 8k3a 12:22
# ��kf4 13:23
# ;`.3e 14:24
# �t{fq 15:25
# 01.7= 16:26
# $d{#� 17:27
# a1*o( 18:28
# 4d>�� 19:29
# a5rz1 20:30
# 4!��0 21:31
# emgc/ 22:32
# q��b� 23:33
# =x~}= 24:34
# ���� 25:35
# (a`o2 26:36
# �`�� 27:37
# 1r`. 28:38
# 0��R� 29:39
# /m}|o 30:40
# ѡO�� 31:41
# =ba=d 32:42
# �P��` 33:43
# 2~ 6% 34:44
# ��2t 35:45
# .?+wo 36:46
# Ą/&� 37:47
# o4j=2 38:48
# �0;� 39:49
# du `t 40:50
# `$�W` 41:51
# %?}&$ 42:52
# t�J2a 43:53
# ob;v3 44:54
# �U/3 45:55
# 2$ka; 46:56
# 0.C� 47:57
# tt|i' 48:58
# `1^�P 49:59
# $ctu  50:60
# aA�  51:61
# 3khr  52:62
# �r  53:63
# ;wor* 54:64
# �or� 55:65
# 'poxs 56:66
# Ppo� 57:67
#  pe!p 58:68
#  p�G  59:69
#  z<"" 60:70
#  �Zr 61:71
# *#?p& 62:72
# �EoRA 63:73
# s mt= 64:74
# pO� 65:75
# prio- 66:76
#  P�� 67:77
# "vr+ 68:78
# ��� 69:79
# &mby( 70:80
# A��  71:81
# =}dz% 72:82
# ...

# %%
# com
hex_len = 10
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " com ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 5&am= 0:10
# t3�l� 1:11
# emopt 2:12
# p�n�a 3:13
# .cr98 4:14
# �b�,� 5:15
#  ~;u; 6:16
# !�.� 7:17
# =7wv0 8:18
# �"��$ 9:19
# t{t}a 10:20
# a��i4 11:21
# 8x,a 12:22
# ��ky4 13:23
# ;s.,e 14:24
# �g{yq 15:25
# 0".(= 16:26
# $w{<� 17:27
# a"*p( 18:28
# 4w>�� 19:29
# a&re1 20:30
# 42��0 21:31
# e~g|/ 22:32
# q��}� 23:33
# =k~b= 24:34
# ���� 25:35
# (r`p2 26:36
# �s�� 27:37
# 1lr. 28:38
# 0��M� 29:39
# /~}co 30:40
# ѲO�� 31:41
# =qa"d 32:42
# �C��` 33:43
# 2m )% 34:44
# ��-t 35:45
# .,+ho 36:46
# ė/9� 37:47
# o'j"2 38:48
# �#;� 39:49
# df t 40:50
# `7�H` 41:51
# %,}9$ 42:52
# t�J-a 43:53
# oq;i3 44:54
# �F/, 45:55
# 27k~; 46:56
# #.\� 47:57
# tg|v' 48:58
# `"^�P 49:59
# $ptj  50:60
# aR�  51:61
# 3xhm  52:62
# �m  53:63
# ;dom* 54:64
# �om� 55:65
# 'cogs 56:66
# Pco� 57:67
#  ce>p 58:68
#  c�X  59:69
#  i<=" 60:70
#  �Zm 61:71
# *0?o& 62:72
# �VoMA 63:73
# s3mk= 64:74
# cO� 65:75
# paip- 66:76
#  C�� 67:77
# "er`+ 68:78
# ��� 69:79
# &~bf( 70:80
# A��ݠ 71:81
# =nde% 72:82
# ...

# %% [markdown]
# # Conjuções

# %%
# mas
hex_len = 10
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " mas ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 5(os= 0:10
# t=�r� 1:11
# ecant 2:12
# p�`�a 3:13
# .m|'8 4:14
# �l�2� 5:15
#  p5k; 6:16
# !� � 7:17
# =9yh0 8:18
# �,��$ 9:19
# tuzca 10:20
# a��w4 11:21
# 8vq2a 12:22
# ��eg4 13:23
# ;} 2e 14:24
# �iugq 15:25
# 0, 6= 16:26
# $yu"� 17:27
# a,$n( 18:28
# 4y0�� 19:29
# a(|{1 20:30
# 4<��0 21:31
# epib/ 22:32
# q��c� 23:33
# =ep|= 24:34
# ��q�� 25:35
# (|nn2 26:36
# �}�� 27:37
# 1b|a. 28:38
# 0��S� 29:39
# /ps}o 30:40
# ѼA�� 31:41
# =o<d 32:42
# �M��` 33:43
# 2c.7% 34:44
# ��3t 35:45
# ."%vo 36:46
# ę!'� 37:47
# o)d<2 38:48
# �-5� 39:49
# dh.at 40:50
# `9�V` 41:51
# %"s'$ 42:52
# t�D3a 43:53
# o5w3 44:54
# �H!2 45:55
# 29e`; 46:56
# - B� 47:57
# tirh' 48:58
# `,P�P 49:59
# $~zt  50:60
# a\�  51:61
# 3vfs  52:62
# �s  53:63
# ;jas* 54:64
# �as� 55:65
# 'mays 56:66
# Pma� 57:67
#  mk p 58:68
#  m�F  59:69
#  g2#" 60:70
#  �Ts 61:71
# *>1q& 62:72
# �XaSA 63:73
# s=cu= 64:74
# mA� 65:75
# pogn- 66:76
#  M�� 67:77
# "k|~+ 68:78
# ��� 69:79
# &plx( 70:80
# A��à 71:81
# =`j{% 72:82
# ...

# %%
# ou
hex_len = 8
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " ou ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 5*{  0:8
# t?�! 1:9
# eau= 2:10
# p�t� 3:11
# .oht 4:12
# �n�a 5:13
#  r!8 6:14
# !�4� 7:15
# =;m; 8:16
# �.� 9:17
# twn0 10:18
# a��$ 11:19
# 8tea 12:20
# ��q4 13:21
# ;4a 14:22
# �ka4 15:23
# 0.4e 16:24
# ${aq 17:25
# a.0= 18:26
# 4{$� 19:27
# a*h( 20:28
# 4>�� 21:29
# er}1 22:30
# q��0 23:31
# =gd/ 24:32
# ��e� 25:33
# (~z= 26:34
# ��� 27:35
# 1`h2 28:36
# 0�� 29:37
# /rg. 30:38
# ѾU� 31:39
# =}{o 32:40
# �O�� 33:41
# 2a:d 34:42
# ��` 35:43
# . 1% 36:44
# ě5t 37:45
# o+po 38:46
# �/!� 39:47
# dj:2 40:48
# `;� 41:49
# % gt 42:50
# t�P` 43:51
# o}!$ 44:52
# �J5a 45:53
# 2;q3 46:54
# /4 47:55
# tkf; 48:56
# `.D� 49:57
# $|n' 50:58
# a^�P 51:59
# 3tr  52:60
# �  53:61
# ;hu  54:62
# �u  55:63
# 'ou* 56:64
# Pou� 57:65
#  os 58:66
#  o� 59:67
#  e&p 60:68
#  �@  61:69
# *<%" 62:70
# �Zu 63:71
# s?w& 64:72
# oUA 65:73
# pms= 66:74
#  O� 67:75
# "ih- 68:76
# �� 69:77
# &rx+ 70:78
# A��� 71:79
# =b~( 72:80
# �Š 73:81
# -d}% 74:82
# ���q 75:83
# +gp: 76:84
# ��$� 77:85
# (jot 78:86
# ...

# %%
# se
hex_len = 8
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " se ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 56k  0:8
# t#�! 1:9
# e}e= 2:10
# p�d� 3:11
# .sxt 4:12
# �r�a 5:13
#  n18 6:14
# !�$� 7:15
# ='}; 8:16
# �2� 9:17
# tk~0 10:18
# a��$ 11:19
# 8hua 12:20
# ��a4 13:21
# ;c$a 14:22
# �wq4 15:23
# 02$e 16:24
# $gqq 17:25
# a2 = 18:26
# 4g4� 19:27
# a6x( 20:28
# 4"�� 21:29
# enm1 22:30
# q��0 23:31
# ={t/ 24:32
# ��u� 25:33
# (bj= 26:34
# �c�� 27:35
# 1|x2 28:36
# 0�� 29:37
# /nw. 30:38
# ѢE� 31:39
# =ako 32:40
# �S�� 33:41
# 2}*d 34:42
# ��` 35:43
# .<!% 36:44
# ć%t 37:45
# o7`o 38:46
# �31� 39:47
# dv*2 40:48
# `'� 41:49
# %<wt 42:50
# t�@` 43:51
# oa1$ 44:52
# �V%a 45:53
# 2'a3 46:54
# 3$ 47:55
# twv; 48:56
# `2T� 49:57
# $`~' 50:58
# aB�P 51:59
# 3hb  52:60
# �  53:61
# ;te  54:62
# �e  55:63
# 'se* 56:64
# Pse� 57:65
#  sos 58:66
#  s� 59:67
#  y6p 60:68
#  �P  61:69
# * 5" 62:70
# �Fe 63:71
# s#g& 64:72
# sEA 65:73
# pqc= 66:74
#  S� 67:75
# "ux- 68:76
# �� 69:77
# &nh+ 70:78
# A��� 71:79
# =~n( 72:80
# �ՠ 73:81
# -xm% 74:82
# ���q 75:83
# +{`: 76:84
# ��4� 77:85
# (vt 78:86
# ...

# %%
# assim
hex_len = 14
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " assim ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 5$}st98 0:14
# t1�r�,� 1:15
# eosn=u; 2:16
# p�r�(� 3:17
# .an'qv0 4:18
# �`�2��$ 5:19
#  |'kr}a 6:20
# !�2��i4 7:21
# =5khy,a 8:22
# � ��my4 9:23
# tyhc(,e 10:24
# a��w}yq 11:25
# 8zc2((= 12:26
# ��wg}<� 13:27
# ;q22,p( 14:28
# �egg8�� 15:29
# 0 26te1 16:30
# $ug"��0 17:31
# a 6na|/ 18:32
# 4u"��}� 19:33
# a$n{xb= 20:34
# 40��y�� 21:35
# e|{bfp2 22:36
# q��c�� 23:37
# =ib|t. 24:38
# ��c��M� 25:39
# (p|n{co 26:40
# �q��I�� 27:41
# 1nnag"d 28:42
# 0��S��` 29:43
# /|a}&)% 30:44
# ѰS��-t 31:45
# =s}<-ho 32:46
# �A��)9� 33:47
# 2o<7l"2 34:48
# ��3=� 35:49
# ..7v&t 36:50
# ĕ3'�H` 37:51
# o%v<{9$ 38:52
# �!'�L-a 39:53
# dd<a=i3 40:54
# `5�V), 41:55
# %.a'm~; 42:56
# t�V3(\� 43:57
# os'wzv' 44:58
# �D32X�P 45:59
# 25w`rj  46:60
# !2B�  47:61
# te`hnm  48:62
# ` B�m  49:63
# $rhtim* 50:64
# aP�im� 51:65
# 3ztsigs 52:66
# �si� 53:67
# ;fssc>p 54:68
# �ss�X  55:69
# 'asy:=" 56:70
# Pas�\m 57:71
#  ay 9o& 58:72
#  a�FiMA 59:73
#  k #kk= 60:74
#  �FsI� 61:75
# *2#qop- 62:76
# �� 63:77
# ...

# %%
# como
hex_len = 12
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " como ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 5&amrt 0:12
# t3�l�a 1:13
# emop;8 2:14
# p�n�.� 3:15
# .cr9w; 4:16
# �b�,� 5:17
#  ~;ut0 6:18
# !�.��$ 7:19
# =7wva 8:20
# �"��k4 9:21
# t{t}.a 10:22
# a��i{4 11:23
# 8x,.e 12:24
# ��ky{q 13:25
# ;s.,*= 14:26
# �g{y>� 15:27
# 0".(r( 16:28
# $w{<�� 17:29
# a"*pg1 18:30
# 4w>��0 19:31
# a&re~/ 20:32
# 42��� 21:33
# e~g|`= 22:34
# q��}�� 23:35
# =k~br2 24:36
# ���� 25:37
# (r`p}. 26:38
# �s��O� 27:39
# 1lrao 28:40
# 0��M�� 29:41
# /~}c d 30:42
# ѲO��` 31:43
# =qa"+% 32:44
# �C��/t 33:45
# 2m )jo 34:46
# ��-;� 35:47
# .,+h 2 36:48
# ė/9� 37:49
# o'j"}t 38:50
# �#;�J` 39:51
# df ;$ 40:52
# `7�H/a 41:53
# %,}9k3 42:54
# t�J-. 43:55
# oq;i|; 44:56
# �F/,^� 45:57
# 27k~t' 46:58
# #.\�P 47:59
# tg|vh  48:60
# `"^�  49:61
# $ptjo  50:62
# aR�o  51:63
# 3xhmo* 52:64
# �mo� 53:65
# ;domes 54:66
# �om� 55:67
# 'cog<p 56:68
# Pco�Z  57:69
#  ce>?" 58:70
#  c�Xo 59:71
#  i<=m& 60:72
#  �ZmOA 61:73
# *0?oi= 62:74
# �VoM� 63:75
# s3mkr- 64:76
# cO�� 65:77
# paipb+ 66:78
#  C��� 67:79
# "er`d( 68:80
# ...

# %% [markdown]
# # Pronomes

# %%
# que
hex_len = 10
for i in range(151):
    if i <= 152 - hex_len:
        print (xor(hex_str[i:i+hex_len], " que ".encode("hex")).decode("hex") + " " + str(i) + ":" + str(i+hex_len))
# Out:
# 54{e= 0:10
# t!�d� 1:11
# euxt 2:12
# p�t�a 3:13
# .qh18 4:14
# �p�$� 5:15
#  l!}; 6:16
# !�4� 7:17
# =%m~0 8:18
# �0��$ 9:19
# tinua 10:20
# a��a4 11:21
# 8je$a 12:22
# ��qq4 13:23
# ;a4$e 14:24
# �uaqq 15:25
# 004 = 16:26
# $ea4� 17:27
# a00x( 18:28
# 4e$�� 19:29
# a4hm1 20:30
# 4 ��0 21:31
# el}t/ 22:32
# q��u� 23:33
# =ydj= 24:34
# ��e�� 25:35
# (`zx2 26:36
# �a�� 27:37
# 1~hw. 28:38
# 0��E� 29:39
# /lgko 30:40
# ѠU�� 31:41
# =c{*d 32:42
# �Q��` 33:43
# 2:!% 34:44
# ��%t 35:45
# .>1`o 36:46
# ą51� 37:47
# o5p*2 38:48
# �1!� 39:49
# dt:wt 40:50
# `%�@` 41:51
# %>g1$ 42:52
# t�P%a 43:53
# oc!a3 44:54
# �T5$ 45:55
# 2%qv; 46:56
# 14T� 47:57
# tuf~' 48:58
# `0D�P 49:59
# $bnb  50:60
# a@�  51:61
# 3jre  52:62
# �e  53:63
# ;vue* 54:64
# �ue� 55:65
# 'quos 56:66
# Pqu� 57:67
#  q6p 58:68
#  q�P  59:69
#  {&5" 60:70
#  �@e 61:71
# *"%g& 62:72
# �DuEA 63:73
# s!wc= 64:74
# qU� 65:75
# pssx- 66:76
#  Q�� 67:77
# "whh+ 68:78
# ��� 69:79
# &lxn( 70:80
# A��ՠ 71:81
# =|~m% 72:82
# ...

# %% [markdown]
# # Guess step

# %%
print(xor(c2[4:20], "continua".encode("hex"))).decode("hex")
# Out:
# desenvol

# %% [markdown]
# # Finding the key using the second message

# %%
print(xor(c2, "a continua expansao da atividade possibilita uma visao das regras de conduta".encode("hex"))).decode("hex")
# Out:
# o desenvolvimento continuo de distintas formas de atuação nao pode distorc

# %% [markdown]
# # Finding the first message using the key

# %%
print(xor(c1, "o desenvolvimento continuo de distintas formas de atuação nao pode distorc".encode("hex"))).decode("hex")
# Out:
# temos que a expansao dos mercados mundiais nos obriga analisar o impacto nas

# %%
m1 = "temos que a expansao dos mercados mundiais nos obriga analisar o impacto nas"
m2 = "a continua expansao da atividade possibilita uma visao das regras de conduta"

# %%
print(xor(m1.encode("hex"), hex_str)).decode("hex")
print(xor(m2.encode("hex"), hex_str)).decode("hex")
# Out:
# a continua expansao da atividade possibilita uma visao das regras de conduta
# temos que a expansao dos mercados mundiais nos obriga analisar o impacto nas

# %%
key = "o desenvolvimento continuo de distintas formas de atuação nao pode distorc".encode("hex")

# %%
_c1 = xor(key, m1.encode("hex"))
print _c1
# Out:
# 1b45090a00451f030a4c1749081d1e15015302004e10061d55024516064100060054041b1a051a410f1c52030e00000b075208131441a2c9a2cf06530f134f4f5006091541071d1c54011310

# %%
_c2 = xor(key, m2.encode("hex"))
print _c2
# Out:
# 0e00070a1d1107181a0d560c15150f1a1c410c4f0a15490f0106560d0141000c5304061d070811490a06060c41064d0545560807140ee3c3a2d04f520b061d41034f00000007061d101a0602

# %%
_c1 == c1
# Out:
# True

# %%
_c2 == c2
# Out:
# True
